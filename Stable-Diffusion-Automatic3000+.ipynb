# %% [markdown]
# <a href="https://colab.research.google.com/github/Born2BeKind/Stable-Diffusion-Automatic-3000/blob/main/Stable-Diffusion-Automatic3000%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # Connect Google Drive
from google.colab import drive
from IPython.display import clear_output
import ipywidgets as widgets
import os

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
Shared_Drive = "" #@param {type:"string"}
#@markdown - Leave empty if you're not using a shared drive

print("[0;33mConnecting...")
drive.mount('/content/gdrive')

if Shared_Drive!="" and os.path.exists("/content/gdrive/Shareddrives"):
  mainpth="Shareddrives/"+Shared_Drive
else:
  mainpth="MyDrive"

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
# Install aria2
# !apt-get install aria2

# Clone the GitHub repository
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui

# Change directory to the cloned repository
# %cd stable-diffusion-webui

# Download models, upscalers,  and extensions using wget
# !wget -c -O models/Stable-diffusion/absolutereality_v181.safetensors https://civitai.com/api/download/models/132760
# !wget -c -O models/VAE/vae-ft-mse-840000-ema-pruned.safetensors https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors
# !wget -c -O models/VAE/kl-f8-anime2.ckpt https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt
# !wget -c -O models/Lora/pytorch_lora_weights.safetensors https://huggingface.co/Jurinovie/Luna-Madre/resolve/main/pytorch_lora_weights.safetensors?download=true
# !wget -c -O models/ESRGAN/4x-UltraSharp.pth https://huggingface.co/Zabin/Resizers/resolve/main/4x-UltraSharp.pth

# %%
# Download embeddings

# !mkdir -p /content/stable-diffusion-webui/embeddings/Negative

# !wget -O /content/stable-diffusion-webui/embeddings/Negative/EasyNegative.pt https://huggingface.co/embed/negative/resolve/main/EasyNegative.pt
# !wget -O /content/stable-diffusion-webui/embeddings/Negative/EasyNegativeV2.safetensors https://huggingface.co/gsdf/Counterfeit-V3.0/resolve/main/embedding/EasyNegativeV2.safetensors
# !wget -O /content/stable-diffusion-webui/embeddings/Negative/bad-hands-5.pt https://huggingface.co/embed/negative/resolve/main/bad-hands-5.pt
# !wget -O /content/stable-diffusion-webui/embeddings/Negative/bad_prompt_version2.pt https://huggingface.co/embed/negative/resolve/main/bad_prompt_version2.pt
# !wget -O /content/stable-diffusion-webui/embeddings/Negative/ng_deepnegative_v1_75t.pt https://huggingface.co/embed/negative/resolve/main/ng_deepnegative_v1_75t.pt
# !wget -O /content/stable-diffusion-webui/embeddings/Negative/bad-artist.pt https://huggingface.co/ffxvs/negative-prompts-pack/resol


# Clone extensions

# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/zanllp/sd-webui-infinite-image-browsing /content/stable-diffusion-webui/extensions/sd-webui-infinite-image-browsing
# !git clone https://github.com/etherealxx/batchlinks-webui /content/stable-diffusion-webui/extensions/batchlinks-webui
# !git clone https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111 /content/stable-diffusion-webui/stable-diffusion-webui/extensions/multidiffusion-upscaler-for-automatic1111
# !git clone https://github.com/mcmonkeyprojects/sd-dynamic-thresholding /content/stable-diffusion-webui/extensions/sd-dynamic-thresholding
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete /content/stable-diffusion-webui/extensions/a1111-sd-webui-tagcomplete
# !git clone https://github.com/aka7774/sd_filer /content/stable-diffusion-webui/extensions/sd_filer
# !git clone https://github.com/Bing-su/adetailer /content/stable-diffusion-webui/extensions/adetailer
# !git clone https://github.com/thomasasfk/sd-webui-aspect-ratio-helper /content/stable-diffusion-webui/extensions/sd-webui-aspect-ratio-helper
# !git clone https://github.com/novitalabs/sd-webui-cleaner /content/stable-diffusion-webui/extensions/sd-webui-cleaner
# !git clone https://github.com/BlafKing/sd-civitai-browser-plus /content/stable-diffusion-webui/7extensions/sd-civitai-browser-plus


# Modify configuration
# !sed -i 's/\["sd_model_checkpoint"\]/\["sd_model_checkpoint","sd_vae","CLIP_stop_at_last_layers"\]/g' modules/shared_options.py
# Out:
# --2024-04-15 20:46:12--  https://huggingface.co/embed/negative/resolve/main/EasyNegative.pt
# Resolving huggingface.co (huggingface.co)... 18.155.68.124, 18.155.68.111, 18.155.68.99, ...
# Connecting to huggingface.co (huggingface.co)|18.155.68.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/7d/70/7d7018f39562b3884528a56f74223b7758c4f27932d5590bf72e479aef78dac5/66a7279a88dd0cb17afbc88560540c638336d5783fd6b191c53c0d654e25b9db?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27EasyNegative.pt%3B+filename%3D%22EasyNegative.pt%22%3B&Expires=1713473172&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=dRStuFCR6QYOCTEFT2v5sA4rknfsib9lrYUvn1jXPaclYJY5ILs-FrFKPvrpkyDlp37%7Ee8r06QhBDRFBNafyguruyMOJOZEavU1ZYeQ3KSZN0Ut3gWQKvkB7pDfcWg2G2TUHXxmNY-vevA4Piu4ezr%7EAVGytUuSLbv3te8z65Xy-9EEII9pNr4%7EkYZC41sT%7EpRJ0cEvIS0QbqNVQJmC5JDfLRKPMV5I77y-x7e-x7pBQbWfQsIM4Y9Gj2vcW4HMerY-gEeDD4mOdS%7EK5B5aBWOZOOp-3qU6osTdo0pyRo%7ElI3uN2f4ccWtaZiTyALRur2XJdupMdjAQkA6p8zTbtiw__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-04-15 20:46:12--  https://cdn-lfs.huggingface.co/repos/7d/70/7d7018f39562b3884528a56f74223b7758c4f27932d5590bf72e479aef78dac5/66a7279a88dd0cb17afbc88560540c638336d5783fd6b191c53c0d654e25b9db?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27EasyNegative.pt%3B+filename%3D%22EasyNegative.pt%22%3B&Expires=1713473172&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=dRStuFCR6QYOCTEFT2v5sA4rknfsib9lrYUvn1jXPaclYJY5ILs-FrFKPvrpkyDlp37%7Ee8r06QhBDRFBNafyguruyMOJOZEavU1ZYeQ3KSZN0Ut3gWQKvkB7pDfcWg2G2TUHXxmNY-vevA4Piu4ezr%7EAVGytUuSLbv3te8z65Xy-9EEII9pNr4%7EkYZC41sT%7EpRJ0cEvIS0QbqNVQJmC5JDfLRKPMV5I77y-x7e-x7pBQbWfQsIM4Y9Gj2vcW4HMerY-gEeDD4mOdS%7EK5B5aBWOZOOp-3qU6osTdo0pyRo%7ElI3uN2f4ccWtaZiTyALRur2XJdupMdjAQkA6p8zTbtiw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.155.68.94, 18.155.68.128, 18.155.68.98, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.155.68.94|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25323 (25K) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/embeddings/Negative/EasyNegative.pt’
#
# /content/stable-dif 100%[===================>]  24.73K  --.-KB/s    in 0s
#
# 2024-04-15 20:46:12 (130 MB/s) - ‘/content/stable-diffusion-webui/embeddings/Negative/EasyNegative.pt’ saved [25323/25323]
#
# --2024-04-15 20:46:13--  https://huggingface.co/gsdf/Counterfeit-V3.0/resolve/main/embedding/EasyNegativeV2.safetensors
# Resolving huggingface.co (huggingface.co)... 18.155.68.4, 18.155.68.99, 18.155.68.111, ...
# Connecting to huggingface.co (huggingface.co)|18.155.68.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/cd/a1/cda186b5f62d61606b3595cd6660dfac2f529c6763be4f402dc61818e353d1d7/339cc9210f70ef842b716588373d95b52351d7e6d111b858e133e3b1e3bd8088?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%
4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/7d/70/7d7018f39562b3884528a56f74223b7758c4f27932d5590bf72e479aef78dac5/54e7e4826d53949a3d0dde40aea023b1e456a618c608a7630e3999fd38f93245?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27ng_deepnegative_v1_75t.pt%3B+filename%3D%22ng_deepnegative_v1_75t.pt%22%3B&Expires=1713473176&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=BvwBANrRD2e1OFDxucpqlr-QKJ6hYJkn2YXMGY8-eYHPh-19YQftNjOc0jItdR1xa7YoTnuI0VWyjP4MkhkSZo8TfBbI44O8dUGPzC3DDfDAF8hBGtPba4oNx2SM4Sht8mSQogON5D-OjQiKPKerw7qB-dts1n8bcj4M6fPtRCQmMSKupQA1Ccp6k72kYgvHYmVPinZbJino1h43Ig0-t8DwEnDohk75ZrXvVY0RM12mkKRDtpnE0Osp93mlI1evyYROC1o2zlCJnsDB733DD4P6vniTVmVm1bjfECjdq79QsxHO%7Ema88nCYO5ncaDeiwqLKA5lAjC7UlKal4tHuFg__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-04-15 20:46:16--  https://cdn-lfs.huggingface.co/repos/7d/70/7d7018f39562b3884528a56f74223b7758c4f27932d5590bf72e479aef78dac5/54e7e4826d53949a3d0dde40aea023b1e456a618c608a7630e3999fd38f93245?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27ng_deepnegative_v1_75t.pt%3B+filename%3D%22ng_deepnegative_v1_75t.pt%22%3B&Expires=1713473176&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=BvwBANrRD2e1OFDxucpqlr-QKJ6hYJkn2YXMGY8-eYHPh-19YQftNjOc0jItdR1xa7YoTnuI0VWyjP4MkhkSZo8TfBbI44O8dUGPzC3DDfDAF8hBGtPba4oNx2SM4Sht8mSQogON5D-OjQiKPKerw7qB-dts1n8bcj4M6fPtRCQmMSKupQA1Ccp6k72kYgvHYmVPinZbJino1h43Ig0-t8DwEnDohk75ZrXvVY0RM12mkKRDtpnE0Osp93mlI1evyYROC1o2zlCJnsDB733DD4P6vniTVmVm1bjfECjdq79QsxHO%7Ema88nCYO5ncaDeiwqLKA5lAjC7UlKal4tHuFg__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.155.68.94, 18.155.68.128, 18.155.68.98, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.155.68.94|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231339 (226K) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/embeddings/Negative/ng_deepnegative_v1_75t.pt’
#
# /content/stable-dif 100%[===================>] 225.92K  --.-KB/s    in 0.006s
#
# 2024-04-15 20:46:16 (39.5 MB/s) - ‘/content/stable-diffusion-webui/embeddings/Negative/ng_deepnegative_v1_75t.pt’ saved [231339/231339]
#
# --2024-04-15 20:46:16--  https://huggingface.co/ffxvs/negative-prompts-pack/resol
# Resolving huggingface.co (huggingface.co)... 18.155.68.4, 18.155.68.99, 18.155.68.111, ...
# Connecting to huggingface.co (huggingface.co)|18.155.68.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-04-15 20:46:16 ERROR 404: Not Found.
#
# fatal: destination path '/content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd-webui-infinite-image-browsing' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/batchlinks-webui' already exists and is not an empty directory.
# Cloning into '/content/stable-diffusion-webui/stable-diffusion-webui/extensions/multidiffusion-upscaler-for-automatic1111'...
# remote: Enumerating objects: 1233, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 1233 (delta 136), reused 136 (delta 120), pack-reused 1029
# Receiving objects: 100% (1233/1233), 1.20 MiB | 4.69 MiB/s, done.
# Resolving deltas: 100% (675/675), done.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd-dynamic-thresholding' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/a1111-sd-webui-tagcomplete' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd_filer' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/adetailer' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd-webui-aspect-ratio-helper' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd-webui-cleaner' already exists and is not an empty directory.
# Cloning into '/content/stable-diffusion-webui/7extensions/sd-civitai-browser-plus'...
# remote: Enumerating objects: 1583, done.
# remote: Counting objects: 100% (365/365), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 1583 (delta 277), reused 217 (delta 202), pack-reused 1218
# Receiving objects: 100% (1583/1583), 13.27 MiB | 16.51 MiB/s, done.
# Resolving deltas: 100% (980/980), done.
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Version: v1.9.0
# Commit hash: adadb4e3c7382bf3e4f7519126cd6c70f4f8557b
# Launching Web UI with arguments: --opt-sdp-attention --enable-insecure-extension-access --disable-safe-unpickle --no-hashing --disable-console-progressbars --theme dark --ngrok 2dIA1h33peIjgM4HSalcg59ZE3y_4PZBEyeXTMoXwiD7PszZ7
# 2024-04-15 20:46:28.391175: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 20:46:28.391228: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 20:46:28.392512: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 20:46:29.588257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# no module 'xformers'. Processing without...
# no module 'xformers'. Processing without...
# No module 'xformers'. Proceeding without it.
# ngrok authtoken detected, trying to connect...
# ngrok connected to localhost:7860! URL: https://aab0-35-198-192-47.ngrok-free.app
# You can use this link after the launch is complete.
# Loading weights [None] from /content/stable-diffusion-webui/stable-diffusion-webui/models/Stable-diffusion/absolutereality_v181.safetensors
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# Startup time: 12.7s (prepare environment: 1.7s, import torch: 4.1s, import gradio: 0.9s, setup paths: 3.2s, initialize shared: 0.2s, other imports: 0.6s, load scripts: 0.7s, create ui: 0.7s, gradio launch: 0.5s).
# Creating model from config: /content/stable-diffusion-webui/stable-diffusion-webui/configs/v1-inference.yaml
# Loading VAE weights specified in settings: /content/stable-diffusion-webui/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors
# Applying attention optimization: sdp... done.
# Model loaded in 3.5s (calculate hash: 0.5s, load weights from disk: 0.7s, create model: 0.5s, apply weights to model: 0.9s, load VAE: 0.1s, load textual inversion embeddings: 0.4s, calculate empty prompt: 0.2s).
# Interrupted with signal 2 in <frame at 0x59cab5ab85b0, file '/usr/lib/python3.10/threading.py', line 324, code wait>
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/launch.py", line 48, in <module>
#     main()
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/launch.py", line 44, in main
#     start()
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/modules/launch_utils.py", line 469, in start
#     webui.webui()
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/webui.py", line 126, in webui
#     server_command = shared.state.wait_for_server_command(timeout=5)
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/modules/shared_state.py", line 63, in wait_for_server_command
#     if self._server_command_signal.wait(timeout):
#   File "/usr/lib/python3.10/threading.py", line 607, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/modules/initialize_util.py", line 164, in sigint_handler
#     print(f'Interrupted with signal {sig} in {frame}')
#   File "/content/stable-diffusion-webui/stable-diffusion-webui/modules/initialize_util.py", line 164, in sigint_handler
#     print(f'Interrupted with signal {sig} in {frame}')
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>

# %%
# Launch the application
# !python3 launch.py --opt-sdp-attention --enable-insecure-extension-access --disable-safe-unpickle --no-hashing --disable-console-progressbars --theme dark --ngrok 2dIA1h33peIjgM4HSalcg59ZE3y_4PZBEyeXTMoXwiD7PszZ7
